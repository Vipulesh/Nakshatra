# %% [markdown]
# <a href="https://colab.research.google.com/github/Vipulesh/Nakshatra/blob/main/Nakshatra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import cv2
from matplotlib.colors import LogNorm

# %%
from astropy.io import fits

# %%
astr = fits.open('/content/0_dss2-blue.fits')
astr.info()
# Out:
# Filename: /content/0_dss2-blue.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     129   (2376, 2381)   int16

# %%
astr[0].header
# Out:
# SIMPLE  =                    T /FITS header
# BITPIX  =                   16 /No.Bits per pixel
# NAXIS   =                    2 /No.dimensions
# NAXIS1  =                 2376 /Length X axis
# NAXIS2  =                 2381 /Length Y axis
# EXTEND  =                    T /
# DATE    = '31/12/22          ' /Date of FITS file creation
# ORIGIN  = 'CASB -- STScI     ' /Origin of FITS image
# PLTLABEL= 'SJ03057           ' /Observatory plate label
# PLATEID = 'A08U              ' /GSSS Plate ID
# REGION  = 'XJ563             ' /GSSS Region Name
# DATE-OBS= '1990/01/29        ' /UT date of Observation
# UT      = '##################' /UT time of observation
# EPOCH   =  1.9900775146480E+03 /Epoch of plate
# PLTRAH  =                    8 /Plate center RA
# PLTRAM  =                   47 /
# PLTRAS  =  5.5976126000001E+01 /
# PLTDECSN= '+                 ' /Plate center Dec
# PLTDECD =                   19 /
# PLTDECM =                   49 /
# PLTDECS =  3.9783190000002E+01 /
# ...

# %%
im_data = astr[0].data
plt.figure()
plt.imshow(im_data/472.5)
im_data=im_data/472.5
plt.colorbar()
plt.show()
print(im_data)
# np.max(numpydata)
# nim=cv2.blur(im_data,(2376,2381))
# plt.imshow(nim,cmap='gray')
# plt.colorbar()
# plt.show()
sns.heatmap(im_data)
# Out:
# [[10.44232804 10.77037037 10.64761905 ... 10.55238095  9.8962963
#    9.56825397]
#  [10.44232804 10.77037037 10.31957672 ... 10.22433862  9.8962963
#    9.56825397]
#  [10.27936508 10.60740741 10.31957672 ...  9.8962963   9.73121693
#    9.73121693]
#  ...
#  [11.25291005 11.25291005 10.67724868 ... 10.04656085  9.88148148
#   10.53756614]
#  [11.25291005 11.25291005 11.00529101 ... 10.04656085  9.55343915
#    9.55343915]
#  [11.19153439 10.86349206 10.55449735 ... 10.3026455   9.64656085
#    9.31851852]]

# %%
df = pd.DataFrame(im_data)
df.head()
# Out:
#         0          1          2          3          4          5     \
# 0  10.442328  10.770370  10.647619  10.319577  10.647619  10.647619
# 1  10.442328  10.770370  10.319577   9.991534   9.991534   9.991534
# 2  10.279365  10.607407  10.319577  10.319577  10.156614   9.828571
# 3   9.951323  10.279365  10.319577  10.319577  10.484656  10.812698
# 4   9.908995  10.237037  10.484656  10.484656  10.647619  10.975661
#
#         6          7          8          9     ...       2366       2367  \
# 0  10.156614  10.156614  10.484656  10.812698  ...  10.304762  10.304762
# 1   9.500529  10.156614  10.484656  10.812698  ...  10.304762   9.648677
# 2   9.663492   9.991534  10.319577  10.647619  ...  10.304762   9.976720
# 3  10.319577   9.991534   9.991534  10.319577  ...   9.976720   9.648677
# 4  10.730159  10.402116  10.402116  10.402116  ...   9.731217   9.731217
#
#         2368       2369       2370       2371       2372       2373  \
# ...

# %%
astro1 = fits.open('/content/0_dss2-red.fits')
astro1.info()
# Out:
# Filename: /content/0_dss2-red.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     129   (2352, 2352)   int16

# %%
astro1[0].header
# Out:
# SIMPLE  =                    T /FITS header
# BITPIX  =                   16 /No.Bits per pixel
# NAXIS   =                    2 /No.dimensions
# NAXIS1  =                 2352 /Length X axis
# NAXIS2  =                 2352 /Length Y axis
# EXTEND  =                    T /
# DATE    = '31/12/22          ' /Date of FITS file creation
# ORIGIN  = 'CASB -- STScI     ' /Origin of FITS image
# PLTLABEL= 'SF02910           ' /Observatory plate label
# PLATEID = 'A0KA              ' /GSSS Plate ID
# REGION  = 'XP563             ' /GSSS Region Name
# DATE-OBS= '1989/11/08        ' /UT date of Observation
# UT      = '##################' /UT time of observation
# EPOCH   =  1.9898533935550E+03 /Epoch of plate
# PLTRAH  =                    8 /Plate center RA
# PLTRAM  =                   47 /
# PLTRAS  =  4.7329825333338E+01 /
# PLTDECSN= '+                 ' /Plate center Dec
# PLTDECD =                   19 /
# PLTDECM =                   51 /
# PLTDECS =  1.4575920000003E+01 /
# ...

# %%
im_data1 = astro1[0].data
plt.figure()
plt.imshow(im_data1/685)
im_data1=im_data1/685
plt.colorbar()
plt.show()
print(im_data1)
# np.max(npd1)
# sns.heatmap(im_data1)
astro1[0].scale('int16')
# nim1=cv2.blur(im_data1,(2352,2352))
# plt.imshow(nim1)
# Out:
# [[16.9080292  17.11094891 16.48467153 ... 16.40437956 16.40437956
#   15.77810219]
#  [16.28175182 15.85839416 16.48467153 ... 16.40437956 16.40437956
#   16.40437956]
#  [16.4379562  16.64087591 16.64087591 ... 15.54306569 16.79562044
#   16.16934307]
#  ...
#  [16.67445255 17.24233577 16.61605839 ... 16.64525547 15.39270073
#   16.64525547]
#  [16.51824818 16.45839416 16.45839416 ... 16.0189781  16.64525547
#   16.0189781 ]
#  [17.14452555 16.45839416 16.45839416 ... 16.64525547 16.0189781
#   16.64525547]]

# %%
df1 = pd.DataFrame(im_data1)
df1.describe
# Out:
# <bound method NDFrame.describe of            0          1          2          3          4          5     \
# 0     16.908029  17.110949  16.484672  16.797080  16.797080  17.110949
# 1     16.281752  15.858394  16.484672  16.797080  16.797080  16.484672
# 2     16.437956  16.640876  16.640876  16.640876  16.640876  17.110949
# 3     17.064234  16.640876  16.640876  16.640876  16.640876  16.484672
# 4     17.064234  17.267153  16.640876  16.953285  16.953285  16.797080
# ...         ...        ...        ...        ...        ...        ...
# 2347  16.360584  16.616058  16.616058  16.616058  17.242336  16.458394
# 2348  16.674453  17.242336  16.616058  16.302190  16.302190  15.832117
# 2349  16.674453  17.242336  16.616058  16.928467  16.928467  16.458394
# 2350  16.518248  16.458394  16.458394  17.084672  16.458394  16.302190
# 2351  17.144526  16.458394  16.458394  17.084672  16.458394  16.928467
#
#            6          7          8          9     ...       2342       2343  \
# ...

# %%
histo=plt.hist(im_data1.flat, bins=10000)
